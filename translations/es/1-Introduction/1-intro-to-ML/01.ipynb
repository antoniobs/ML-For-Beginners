# %%
print (":-)")
# Out:
# :-)

# %%
name = "Caballero!"
print(f"Hola {name}")
# Out:
# Hola Caballero!

# %%
numbers = [1, 2, 3, 4, 5]
sum(numbers)
# Out:
# 15

# %% [markdown]
# https://excalidraw.com/

# %% [markdown]
# Microsoft Foundry for AI
#
#
# ![Mi imagen](imgs/image.png)
#
# https://ai.azure.com/home
#
#
# Microsoft Foundry endpoints
#
# ![Mi imagen](imgs/image2.png)
#
# ```
#  Generative AI
#              │
#       ┌──────┴──────┐
#       │             │
#  Cloud LLMs       SLMs
#       │             │
#  GPT / etc.       Phi
#       │             │
#       └──────┬──────┘
#              │
#           .NET
#              │
#       Semantic Kernel
#              │
#        Mi aplicación
# ```
